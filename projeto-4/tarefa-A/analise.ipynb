# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Importando os dados em CSV do Fortran

# %%
theta_e = pd.read_csv('./saida-a-13687303-theta_t.csv', sep=',', header=0)
e_e = pd.read_csv('./saida-a-13687303-e_t.csv', sep=',', header=0)
theta_ec = pd.read_csv('./saida-a-13687303-theta_ec_t.csv', sep=',', header=0)
e_ec = pd.read_csv('./saida-a-13687303-e_ec_t.csv', sep=',', header=0)

# %% [markdown]
# # Gráficos

# %% [markdown]
# ## Método de Euler

# %% [markdown]
# - Gráfico de $\theta(t)$

# %%
f1, ax1 = plt.subplots()
ax1.plot(theta_e['t'], theta_e['theta'], label='$\\theta(t)$')
ax1.set_xlabel('Tempo (s)')
ax1.set_ylabel('$\\theta$ (rad)')
ax1.grid()
ax1.legend()
f1.savefig('./tarefa-a-graf-1-13687303.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# - Gráfico de $E(t)$

# %%
f2, ax2 = plt.subplots()
ax2.plot(e_e['t'], e_e['e'], label='$E(t)$')
ax2.set_xlabel('Tempo (s)')
ax2.axhline(np.mean(e_e['e']), color='red', label='E média')
ax2.axhline(e_e['e'][0], color='green', label='$E_0$')
ax2.set_ylabel('Energia (J)')
ax2.grid()
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True, ncol=3)
f2.savefig('./tarefa-a-graf-2-13687303.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Método de Euler-Cromer

# %% [markdown]
# - Gráfico de $\theta(t)$

# %%
f3, ax3 = plt.subplots()
ax3.plot(theta_ec['t'], theta_ec['theta_ec'], label='$\\theta(t)$')
ax3.set_ylabel("$\\theta$ (rad)")
ax3.set_xlabel('Tempo (s)')
ax3.grid()
ax3.legend()
f3.savefig('./tarefa-a-graf-3-13687303.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# - Gráfico de $E(t)$

# %%
f4, ax4 = plt.subplots()
ax4.plot(e_ec['t'], e_ec['e_ec'], label='$E (t)$')
ax4.axhline(np.mean(e_ec['e_ec']), color='red', label='E média')
ax4.axhline(e_ec['e_ec'][0], color='green', label='$E_0$')
ax4.set_ylabel('Energia (J)')
ax4.set_xlabel('Tempo (s)')
ax4.grid()
ax4.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12),
          fancybox=True, shadow=True, ncol=3)
f4.savefig('./tarefa-a-graf-4-13687303.pdf', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Comparação entre os métodos

# %% [markdown]
# - Gráfico de $\theta(t)$

# %%
f5, ax5 = plt.subplots()
ax5.plot(e_e['t'], e_e['e'], label='Euler')
ax5.plot(e_ec['t'], e_ec['e_ec'], label='Euler-Cromer')
ax5.set_ylabel('Energia (J)')
ax5.set_xlabel('Tempo (s)')
ax5.legend()
ax5.grid()
f5.savefig('./tarefa-a-graf-5-13687303.pdf', dpi=300, bbox_inches='tight')
